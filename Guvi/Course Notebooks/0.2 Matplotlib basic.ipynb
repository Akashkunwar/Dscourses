# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
x=np.arange(1,10)
y1=[45,23,12,62,15,20,45,56,33]
y2=[78,3,52,32,75,10,-45,66,63]
plt.plot(x,y1)
plt.plot(x,y2)
plt.show()

# %%
x=np.arange(1,10)
y1=[45,23,12,62,15,20,45,56,33]
y2=[78,3,52,32,75,10,-45,66,63]
plt.plot(x,y1)
plt.show()
plt.plot(x,y1)
plt.plot(x,y2)
plt.show()

# %%
x=np.arange(1,10)
s1=[45,23,12,62,15,20,45,40,33]
s2=[78,3,52,32,75,10,-45,20,3]
plt.plot(x,s1,label="sensor 1")
plt.plot(x,s2,label="sensor 2")
plt.xlabel("x axis")
plt.ylabel("y axis")
plt.title("sample")
plt.legend()
plt.show()

# %%
s1=[45,23,12,62,15,20,45,40,33]
plt.plot(s1,marker="<",ms=20,mec="k",mfc="#F1C40F")
plt.show()

# %%
s1=[45,23,12,62,15,20,45,40,33]
plt.plot(s1,marker="<",linestyle="dashed")
plt.show()

# %% [markdown]
# - solid
# : dotted
# -. dashdot
# -- dashed
# None

# %%
s1=[45,23,12,62,15,20,45,40,33]
plt.plot(s1,marker="<",ls="None")
plt.show()

# %%
s1=[45,23,12,62,15,20,45,40,33]
plt.plot(s1,marker="<",color="r",ls="-",linewidth=1,mec="k",mfc="#F1C40F")
plt.show()

# %%
t=[1,2,3,4,5,6,7,8,9]
s1=[45,23,12,62,15,20,45,40,33]
s2=[78,3,52,32,75,10,-45,20,3]
plt.bar(t,s1)
plt.bar(t,s2)
plt.show()

# %%
t=[1,2,3,4,5,6,7,8,9]
s1=[45,23,12,62,15,20,45,40,33]
s2=[78,3,52,32,75,10,-45,20,3]
plt.bar(t,s2,color="k")
plt.bar(t,s1,color="g")
plt.show()

# %%
t=[1,2,3,4,5,6,7,8,9]
s1=[45,23,12,62,15,20,45,40,33]
plt.bar(t,s1,color="g",width=0.8)
plt.show()

# %%
t=[1,2,3,4,5,6,7,8,9]
s1=[45,23,12,62,15,20,45,40,56]
s2=[78,3,52,32,75,10,-45,20,3]
plt.bar(t,s2,color="k")
plt.bar(t,s1,color="g",width=0.4)
plt.show()

# %%
t=[1,2,3,4,5,6,7,8,9]
s1=[45,23,12,62,15,20,45,40,56]
plt.barh(t,s1,color="g",height=0.2)
plt.show()

# %%
s1=[45,23,12,62,23,23,45,12,30]
plt.hist(s1)
plt.show()

# %%
n=np.random.randn(100)
n
# Out:
# array([-1.24209046, -1.26472993, -0.4210694 ,  0.49367223,  0.3221004 ,
#        -1.24020634, -1.18815141,  1.11692127,  0.81016238,  1.45002908,
#         1.30660002, -1.50365641,  0.82593223,  0.52055268, -0.20816818,
#        -1.53980645,  2.09008663,  0.27929783, -0.78649103,  0.25392794,
#         1.60761393, -0.79806639,  0.48774923,  1.1774819 ,  0.41648573,
#        -2.7009342 ,  1.03585118, -0.62599276, -0.03083588,  3.11759809,
#         1.40328598,  0.23566543, -1.14679717, -1.57949675, -0.19336788,
#         0.3171522 ,  0.41090631, -0.58304119,  1.66513584, -0.97294511,
#        -0.48633951, -0.8186539 , -0.26656109,  1.96556555,  0.32913783,
#         0.48475539,  0.62113042, -1.6114758 ,  1.67019112, -0.29160133,
#         0.68167838,  0.41924209,  0.16403299, -0.29779403,  1.79815602,
#         0.16202879, -1.29325373, -0.16490287,  0.59598843, -0.44600993,
#         0.53478948,  0.99513681,  2.3485279 , -0.70492815, -0.52921111,
#        -1.1573218 ,  1.82832964, -0.17910578, -0.43507606, -0.83037299,
#        -0.9909157 , -0.82020698,  2.7201743 , -0.252333  , -0.46508532,
#        -0.85562193,  0.5427722 , -1.7789908 ,  0.16201584,  2.74822084,
#         0.52133294,  1.07963539, -0.07405932,  1.29235825,  0.12724542,
#         1.1074754 ,  0.83101542,  0.99448099, -0.06232978, -0.81619279,
#        -2.64641866,  0.52512982, -0.26784139,  0.60127853,  1.08250657,
#        -0.02259304,  1.82850556, -1.09654349,  0.59993607, -0.99263648])

# %%
x.min(),x.max()
# Out:
# (0, 19)

# %%
x=np.random.uniform(0,20,100).astype(int)
plt.hist(x,bins=20)
plt.show()

# %%
x=15+np.random.randn(1000)
x.mean()
# Out:
# 15.010011433941443

# %%
np.random.randn(20)
# Out:
# array([ 0.37423589, -0.19434609,  0.87951476,  1.15665056,  1.44980732,
#         1.70047899,  2.2158728 ,  0.34596231, -0.65522019,  1.2006391 ,
#        -0.67207706, -0.84706039,  0.16959347,  1.01617928,  0.46840371,
#         0.1124031 ,  0.11799569,  1.81707034, -0.47395524,  0.86344343])

# %%
x=15+np.random.randn(1000)
print(x.min(),x.max())
plt.hist(x,bins=20)
plt.show()
# Out:
# 11.78415204754394 18.588261162162905

# %%
(x.max()-x.min())/20
# Out:
# 0.3425568464213825

# %%
x.min() , x.min()+((x.max()-x.min())/5) , x.min()+((x.max()-x.min())/5)*2
# Out:
# (11.838315996579885, 13.072866227759066, 14.307416458938249)

# %%
x=15+np.random.randn(1000)
m=[m for m in range(len(x))]
plt.bar(m,x)
plt.show()
plt.hist(x,bins=20)
plt.show()
plt.hist(x,cumulative=True,bins=20)
plt.show()

# %%
t=[1,2,3,4,5,6,7,8,9]
s1=[45,23,12,62,15,20,45,40,56]
plt.scatter(t,s1,color="r",marker="v")
plt.show()

# %%
t=[1,2,3,4,5,6,7,8,9]
s1=[45,23,12,62,15,20,45,40,56]
s2=[12,56,32,-100,10,3,56,23,32]
s3=[75,23,22,30,15,10,35,22,6]

#plt.plot([],[],color="r",label="sensor1")
#plt.plot([],[],color="k",label="sensor2")
#plt.plot([],[],color="c",label="sensor3")

plt.stackplot(t,s1,s2,s3,colors=["r","k","c"],labels=["a","b","c"])
plt.legend()
plt.show()

# %%
s1=[100,45,16,84]
plt.pie(s1,labels=["a","b","c","d"])
plt.show()

# %%
s1=[100,45,16,84]
plt.pie(s1,labels=["a","b","c","d"],startangle=90)
plt.show()

# %%
s1=[100,45,16,84]
plt.pie(s1,labels=["a","b","c","d"],startangle=90,explode=[0.2,0.1,0,0],colors=["r","k","c","m"],shadow=True)
plt.legend(title="sensor")
plt.show()
